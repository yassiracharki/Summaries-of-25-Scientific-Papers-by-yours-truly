# %% [markdown]
# <a href="https://www.kaggle.com/code/yacharki/summaries-of-25-scientific-papers-by-yours-truly?scriptVersionId=197005631" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **📚 My Summaries of 25 Scientific Papers all related to Deep Learning and NLP 📚**
#
#
# ![d41586-018-02404-4_15480054.jpg](attachment:12665e0b-fd01-4fe2-ad9a-2aeca83374fb.jpg)
#
# **In this notebook, you will find a short (1-10 pages), summarie of 25 scientifique papers (Articles/reviews/conference papers etc ...)**
# # Attention: The Pictures are not the full summary, it's just an overview, visit the link below the picture for the full summary
# **All these Summaries are writen by me Acharki Yassir, in light of my Master's Degree Final Project**
#
# # The list of all the DOIs (Digital Object Identifiers) :
#
# [1] **Wadawadagi, R., Pagi, V. Sentiment analysis with deep neural networks: comparative study and
# performance assessment. Artif Intell Rev 53, 6155–6195 (2020).**
#
# [2] **Agüero-Torales, Marvin M., José I. Abreu Salas, and Antonio G. López-Herrera. "Deep learning and
# multilingual sentiment analysis on social media data: An overview." Applied Soft Computing 107 (2021):
# 107373.**
#
# [3] **Tang, Duyu, et al. "Sentiment embeddings with applications to sentiment analysis." IEEE transactions on
# knowledge and data Engineering 28.2 (2015): 496-509.**
#
# [4] **Duncan, Brett, and Yanqing Zhang. "Neural networks for sentiment analysis on Twitter." 2015 IEEE
# 14th International Conference on Cognitive Informatics & Cognitive Computing (ICCI* CC). IEEE, 2015.**
#
# [5] **Zimbra, David, Manoochehr Ghiassi, and Sean Lee. "Brand-related Twitter sentiment analysis using
# feature engineering and the dynamic architecture for artificial neural networks." 2016 49th Hawaii
# International Conference on System Sciences (HICSS). IEEE, 2016.**
#
# [6] **Shazly, Khadija, Marwa Eid, and Hanaa Salem. "An Efficient Hybrid Approach for Twitter Sentiment
# Analysis based on Bidirectional Recurrent Neural Networks." International Journal of Computer
# Applications 175.17 (2020): 32-36.**
#
# [7] **Gao, Zhengjie, et al. "Target-dependent sentiment classification with BERT." Ieee Access 7 (2019):
# 154290-154299.**
#
# [8] **Basiri, Mohammad Ehsan, et al. "A novel fusion-based deep learning model for sentiment analysis of
# COVID-19 tweets." Knowledge-Based Systems 228 (2021): 107242.**
#
# [9] **Colón-Ruiz, Cristóbal, and Isabel Segura-Bedmar. "Comparing deep learning architectures for sentiment
# analysis on drug reviews." Journal of Biomedical Informatics 110 (2020): 103539.**
#
# [10] **Liu, Siru, and Jialin Liu. "Public attitudes toward COVID-19 vaccines on English-language Twitter: A
# sentiment analysis." Vaccine 39.39 (2021): 5499-5505.**
#
# [11] **Applications of Deep Learning to Sentiment Analysis of Movie Reviews.**
#
# [12] **Shaukat, Zeeshan, et al. "Sentiment analysis on IMDB using lexicon and neural networks." SN Applied
# Sciences 2.2 (2020): 1-10.**
#
# [13] **Preethi, G., et al. "Application of deep learning to sentiment analysis for recommender system on
# cloud." 2017 International conference on computer, information and telecommunication systems (CITS).
# IEEE, 2017.**
#
# [14] **Li, Wei, et al. "BiERU: Bidirectional emotional recurrent unit for conversational sentiment
# analysis." Neurocomputing 467 (2022): 73-82.**
#
# [15] **Pham, Duc-Hong, and Anh-Cuong Le. "Exploiting multiple word embeddings and one-hot character
# vectors for aspect-based sentiment analysis." International Journal of Approximate Reasoning 103 (2018):
# 1-10.**
#
# [16] **Kotelnikova, A. V. "Comparison of Deep Learning and Rule-based Method for the Sentiment Analysis
# Task." 2020 International Multi-Conference on Industrial Engineering and Modern Technologies
# (FarEastCon). IEEE, 2020.**
#
# [17] **Xu, Guixian, et al. "Sentiment analysis of comment texts based on BiLSTM." Ieee Access 7 (2019):
# 51522-51532.**
#
# [18] **Dang, Nhan Cach, María N. Moreno-García, and Fernando De la Prieta. "Sentiment analysis based on
# deep learning: A comparative study." Electronics 9.3 (2020): 483.**
#
# [19] **Jain, Anuja P., and Padma Dandannavar. "Application of machine learning techniques to sentiment
# analysis." 2016 2nd International Conference on Applied and Theoretical Computing and Communication
# Technology (iCATccT). IEEE, 2016.**
#
# [20] **Al-Saqqa, Samar, Ghazi Al-Naymat, and Arafat Awajan. "A large-scale sentiment data classification
# for online reviews under apache spark." Procedia Computer Science 141 (2018): 183-189.**
#
# [21] **Assiri, Adel, Ahmed Emam, and Hmood Al-Dossari. "Real-time sentiment analysis of Saudi dialect
# tweets using SPARK." 2016 IEEE International Conference on Big Data (Big Data). IEEE, 2016.**
#
# [22] **Bhuvan, Malladihalli S., et al. "Semantic sentiment analysis using context specific
# grammar." International Conference on Computing, Communication & Automation. IEEE, 2015.**
#
# [23] **Das, Sushree, Ranjan Kumar Behera, and Santanu Kumar Rath. "Real-time sentiment analysis of twitter
# streaming data for stock prediction." Procedia computer science 132 (2018): 956-964.**
#
# [24] **Gupta, Anand, et al. "A big data analysis framework using apache spark and deep learning." 2017 IEEE
# international conference on data mining workshops (ICDMW). IEEE, 2017.**
#
# [25] **Alsheikh, Mohammad Abu, et al. "Mobile big data analytics using deep learning and apache
# spark." IEEE network 30.3 (2016): 22-29.**
#
# [26] **Chowdhary, K. R. Fundamentals of artificial intelligence. New Delhi: Springer India, 2020.**

# %% [markdown]
# # Article 1 : Sentiment analysis with deep neural networks comparative study and performance assessment
#
# <img alt=""  src="https://i.imgur.com/osiPZSI.png">
#
# Link :
# https://docs.google.com/document/d/1Ybwje0Jax5JWTgt3wGo-SZz0EcOYWw2J/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 2 : Deep learning and multilingual sentiment analysis on social media data: An overview
#
# <img alt=""  src="https://i.imgur.com/9ASCmXf.png">
#
# Link :
# https://docs.google.com/document/d/1n_jYX0Hw2rbkTAVxABvupc_DzFhl_q9u/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 3 : Sentiment Embeddings with Applications to Sentiment Analysis.
#
# <img alt=""  src="https://i.imgur.com/VANQxd9.png">
#
# Link :
# https://docs.google.com/document/d/1a-BE0dBBgereh-VoUD-iMQkadVtGEXOp/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 4 : Neural Networks for Sentiment Analysis on Twitter.
#
# <img alt=""  src="https://i.imgur.com/wv8GSqx.png">
#
# Link :
# https://docs.google.com/document/d/1N-SDFFPlkXvOT4yqpGmIy4jw9eEAkL4f/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 5 : Brand-Related Twitter Sentiment Analysis using Feature Engineering and the Dynamic Architecture for Artificial Neural Networks.
#
# <img alt=""  src="https://i.imgur.com/Sm6o4Em.png">
#
# Link :
# https://docs.google.com/document/d/1K00Q8f3PLElA-ZFZ6gWKeWbIqaYIWHXA/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 6 : An Efficient Hybrid Approach for Twitter Sentiment Analysis Based on Bidirectional Recurrent Neural Networks.
#
# <img alt=""  src="https://i.imgur.com/4GhCK0t.png">
#
# Link :
# https://docs.google.com/document/d/1W_k3ICzV_Mgd1mB72bZiC-8WzY-JYbnB/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 7 : Target-Dependent Sentiment Classification with BERT.
#
# <img alt=""  src="https://i.imgur.com/VmDjT0Q.png">
#
# Link :
# https://docs.google.com/document/d/1xVSNn4M0uP8Ll7R6Zzcv3aZ78K6LI2tW/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 8 : A novel fusion-based deep learning model for sentiment analysis of COVID-19 tweets.
#
# <img alt=""  src="https://i.imgur.com/3IG7Swf.png">
#
# Link :
# https://docs.google.com/document/d/1Ydl8evJv07BCl6lLTE-t2gRjEZulZ-na/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 9 : Comparing deep learning architectures for sentiment analysis on drug reviews.
#
# <img alt=""  src="https://i.imgur.com/VR6DLsh.png">
#
# Link :
# https://docs.google.com/document/d/1szdpzJiZI7Lfwnb9O3OT5l9Nt5ceNv-E/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 10 : Public attitudes toward COVID 19 vaccines on English language Twitter: A sentiment analysis.
#
# <img alt=""  src="https://i.imgur.com/kVGFIw5.png">
#
# Link :
# https://docs.google.com/document/d/1fEeomPfrQmY9ChikOR6uBR-uz_NmLDye/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 11 : Applications of Deep Learning to Sentiment Analysis of Movie Reviews.
#
# <img alt=""  src="https://i.imgur.com/jqoZ886.png">
#
# Link :
# https://docs.google.com/document/d/1KM0FA0RrMjQKHZXHT3Of7GR7LfCfPODB/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 12 : Sentiment analysis on IMDB using lexicon and neural networks.
#
# <img alt=""  src="https://i.imgur.com/NKnVzJQ.png">
#
# Link :
# https://docs.google.com/document/d/1geuWc2-K9F55qYjBtNuv8_ICKb17I4su/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 13 : Application of Deep Learning to Sentiment Analysis for Recommender System on Cloud.
#
# <img alt=""  src="https://i.imgur.com/lhctvY4.png">
#
# Link :
# https://docs.google.com/document/d/1syA-j7noS2WyqyjvlSi6tSxjMZXEJXmy/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 14 : BiERU Bidirectional emotional recurrent unit for conversational.
#
# <img alt=""  src="https://i.imgur.com/OEHh1G0.png">
#
# Link :
# https://docs.google.com/document/d/1U9YKZCw-rAI5RPKczdHWu4afWf1kEJ2h/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 15 : Exploiting multiple word embeddings and one-hot character vectors for aspect-based sentiment analysis.
#
# <img alt=""  src="https://i.imgur.com/KWy6Hna.png">
#
# Link :
# https://docs.google.com/document/d/1a94oJ-geHEgCfU4mex3FP6Vk6SIAeYps/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 16 : Comparison of Deep Learning and Rule-based Method for the Sentiment Analysis Task.
#
# <img alt=""  src="https://i.imgur.com/3zPDqNP.png">
#
# Link :
# https://docs.google.com/document/d/1zlg_qhN_6Yixi5IH-MdgLZkrUAknz_MA/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 17 : Sentiment Analysis of Comment Texts Based on BiLSTM.
#
# <img alt=""  src="https://i.imgur.com/JXi6dWG.png">
#
# Link :
# https://docs.google.com/document/d/1Mywxpo1KU_Ieu8MEHZtf45BljE6LCMUB/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 18 : Sentiment Analysis Based on Deep Learning: A Comparative Study.
#
# <img alt=""  src="https://i.imgur.com/I9pKYY5.png">
#
# Link :
# https://docs.google.com/document/d/1rkdunNp1-y39C9fCKPGVmulM9QI0WDEV/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 19 : Application of Machine Learning Techniques to Sentiment Analysis.
#
# <img alt=""  src="https://i.imgur.com/KuzU3ij.png">
#
# Link :
# https://docs.google.com/document/d/1zqoK7kR9hf1d-_yf1amfX3ibYMH9wNds/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 20 : A Large-Scale Sentiment Data Classification for Online Reviews Under Apache Spark.
#
# <img alt=""  src="https://i.imgur.com/8JOPCOx.png">
#
# Link :
# https://docs.google.com/document/d/1mgxfCP5io2vpwUWAHsE_3Zv9BeeVXnF7/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 21 : Real-Time Sentiment Analysis of Saudi Dialect Tweets Using SPARK.
#
# <img alt=""  src="https://i.imgur.com/hxoCUN4.png">
#
# Link :
# https://docs.google.com/document/d/1dUJrXZjxTZebyK0DTFvfP2KAl0p04NB3/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 22 : Semantic Sentiment Analysis Using Context Specific.
#
# <img alt=""  src="https://i.imgur.com/oAvUv4b.png">
#
# Link :
# https://docs.google.com/document/d/1fJZtri4q9cTyMOiOfhB9c_ir9KdrR8K9/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 23 : Real-Time Sentiment Analysis of Twitter Streaming data for Stock Prediction.
#
# <img alt=""  src="https://i.imgur.com/PqHjU7Z.png">
#
# Link :
# https://docs.google.com/document/d/1qrLHbx1ZdlyNndx0vDafAqPSS8F0OYuU/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 24 : A Big Data Analysis Framework Using Apache Spark and Deep Learning.
#
# <img alt=""  src="https://i.imgur.com/ZUZtGyR.png">
#
# Link :
# https://docs.google.com/document/d/1_XhwZi_7vSObA5qF3ix0EJfkZuuXhZ3e/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # Article 25 : Mobile Big Data Analytics Using Deep Learning and Apache Spark.
#
# <img alt=""  src="https://i.imgur.com/l1c6G7j.png">
#
# Link :
# https://docs.google.com/document/d/1lbiTDn2C8YdeTR0llpbro-vRTRkUz9iz/edit?usp=sharing&ouid=118211520465372746483&rtpof=true&sd=true

# %% [markdown]
# # + Just a friendly reminder, I have read and summarised these Papers Personally, this ins't a copy pasted notebook, feel free to **Reach Out** on Kaggle or Linkedin.
